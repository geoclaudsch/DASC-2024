# %% [markdown]
# # Statistische Modelle - Beispiel Visualisierung

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from matplotlib.colors import ListedColormap

from sklearn import datasets, neighbors
from sklearn.inspection import DecisionBoundaryDisplay

# %%
# importieren des IRIS-Datensatzes
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## Metadaten:
# Der berühmte Iris-Datensatz:
# Der Datensatz besteht aus 50 Messungen von drei Arten der Pflanze Iris (Iris setosa, Iris virginica and Iris versicolor). Es wurden jeweils die 4 Merkmale vermessen: Länge und Breite der Kelchblätter sowie Länge und Breite der Kronblätter (jeweils in cm). Basierend auf der Kombination der vier Grundmerkmale entwickelte Fischer (1936) eine Möglichkeit, diese Arten voneinander zu unterscheiden. Dieser Datensatz ist ein grundlegender Testdatensatz für verschiedene ML-Anwendungen.
# Quellen:
# * R. A. Fisher (1936). "The use of multiple measurements in taxonomic problems". Annals of Eugenics. 7 (2): 179–188. doi:10.1111/j.1469-1809.1936.tb02137.x. hdl:2440/15227
# * https://en.wikipedia.org/wiki/Iris_flower_data_set

# %% [markdown]
# # Darstellung von möglichen Abhängigkeiten - Pair plot

# %%
sns.pairplot(iris)
plt.show()

# %% [markdown]
# ## Abhängigkeiten ausgewählter Variablen

# %%
sns.pairplot(data=iris, vars=["sepal_width", "sepal_length"])
plt.show()

# %% [markdown]
# ## Farblich kodiert für jede Spezies macht es deutlicher

# %%
sns.pairplot(iris,hue="species")
plt.show()

# %% [markdown]
# Daran würde sich die kNN-Analyse anschließen - intuitiv sieht man anhand der letzten Grafik die Auswahl des Features Petal (length, width) eignet sich besser zur Klassifizierung!

# %% [markdown]
# ## Noch ein paar Feinheiten...
# z.B. mal als Bild abspeichern

# %%
pairplot= sns.pairplot(iris,hue="species",markers=["o", "s", "D"], palette="rocket", diag_kind="hist", corner=True)
pairplot.savefig('pairplot.png', dpi=300)
plt.show()

# %%
sns.pairplot(iris, hue="species", kind="hist")
plt.show()

# %% [markdown]
# ## KDE-Plots
# A kernel density estimate (KDE) plot is a method for visualizing the distribution of observations in a dataset, analogous to a histogram. KDE represents the data using a continuous probability density curve in one or more dimensions. (Darstellung als Kontourenplot)

# %%
ax=sns.pairplot(iris, diag_kind="kde", corner = True)
ax.map_lower(sns.kdeplot, levels=3, color = "darkred", alpha = 0.8)
plt.show()

# %%
sns.jointplot(data=iris, x="petal_length", y="petal_width", marker="o", hue="species")
plt.show()
