# %%
import matplotlib.pyplot as plt
#%matplotlib inline

# %%
def func_id(x):
    return x

# %%
#Initialisierung

x = 0.2
y = x
eta = 1.2

weight = -10
weights = []
errors = []
w_deltas = []

# %%
#Tabelle

print("Input x = {:.6f}, Gewünschter Output y = {:.2f}".format(x,y))
print("{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}".format('Iter', 'x', 'w',
                                                        'n_input', 'act', 'y_hat', 'y', 'E', 'E_', 'w_delta'))

for step in range(10):
    net_i = weight*x
    activation = func_id(net_i)
    y_hat = activation
    error = 0.5*(y-y_hat)**2
    derivative = (-1.0)*x*(y-y_hat)
    w_delta = (-1.0)*derivative*eta
    weights.append(weight)
    errors.append(error)
    w_deltas.append(w_delta)

    if step % 1 == 0:
        print("{}\t{}\t{:6.2f}\t{:5.2f}\t{:5.2f}\t{:5.2f}\t{:.2f}\t{:.4f}\t{:.4f}\t{:.4f}"
              .format(step, x, weight, net_i, activation, y_hat, y, error, derivative, w_delta))

    weight += w_delta
# Out:
# Input x = 0.200000, Gewünschter Output y = 0.20
# Iter	x	w	n_input	act	y_hat	y	E	E_	w_delta
# 0	0.2	-10.00	-2.00	-2.00	-2.00	0.20	2.4200	-0.4400	0.5280
# 1	0.2	 -9.47	-1.89	-1.89	-1.89	0.20	2.1933	-0.4189	0.5027
# 2	0.2	 -8.97	-1.79	-1.79	-1.79	0.20	1.9878	-0.3988	0.4785
# 3	0.2	 -8.49	-1.70	-1.70	-1.70	0.20	1.8015	-0.3796	0.4556
# 4	0.2	 -8.04	-1.61	-1.61	-1.61	0.20	1.6327	-0.3614	0.4337
# 5	0.2	 -7.60	-1.52	-1.52	-1.52	0.20	1.4797	-0.3441	0.4129
# 6	0.2	 -7.19	-1.44	-1.44	-1.44	0.20	1.3411	-0.3275	0.3931
# 7	0.2	 -6.80	-1.36	-1.36	-1.36	0.20	1.2154	-0.3118	0.3742
# 8	0.2	 -6.42	-1.28	-1.28	-1.28	0.20	1.1016	-0.2969	0.3562
# 9	0.2	 -6.07	-1.21	-1.21	-1.21	0.20	0.9983	-0.2826	0.3391

# %%
#Tabelle

print("Input x = {:.6f}, Gewünschter Output y = {:.2f}".format(x,y))
print("{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}\t{}".format('Iter', 'x', 'w',
                                                        'n_input', 'act', 'y_hat', 'y', 'E', 'E_', 'w_delta'))

for step in range(121):
    net_i = weight*x
    activation = func_id(net_i)
    y_hat = activation
    error = 0.5*(y-y_hat)**2
    derivative = (-1.0)*x*(y-y_hat)
    w_delta = (-1.0)*derivative*eta
    weights.append(weight)
    errors.append(error)
    w_deltas.append(w_delta)

    if step % 10 == 0:
        print("{}\t{}\t{:6.2f}\t{:5.2f}\t{:5.2f}\t{:5.2f}\t{:.2f}\t{:.4f}\t{:.4f}\t{:.4f}"
              .format(step, x, weight, net_i, activation, y_hat, y, error, derivative, w_delta))

    weight += w_delta
# Out:
# Input x = 0.200000, Gewünschter Output y = 0.20
# Iter	x	w	n_input	act	y_hat	y	E	E_	w_delta
# 0	0.2	 -5.73	-1.15	-1.15	-1.15	0.20	0.9048	-0.2690	0.3229
# 10	0.2	 -3.11	-0.62	-0.62	-0.62	0.20	0.3383	-0.1645	0.1974
# 20	0.2	 -1.51	-0.30	-0.30	-0.30	0.20	0.1265	-0.1006	0.1207
# 30	0.2	 -0.54	-0.11	-0.11	-0.11	0.20	0.0473	-0.0615	0.0738
# 40	0.2	  0.06	 0.01	 0.01	 0.01	0.20	0.0177	-0.0376	0.0451
# 50	0.2	  0.43	 0.09	 0.09	 0.09	0.20	0.0066	-0.0230	0.0276
# 60	0.2	  0.65	 0.13	 0.13	 0.13	0.20	0.0025	-0.0141	0.0169
# 70	0.2	  0.79	 0.16	 0.16	 0.16	0.20	0.0009	-0.0086	0.0103
# 80	0.2	  0.87	 0.17	 0.17	 0.17	0.20	0.0003	-0.0053	0.0063
# 90	0.2	  0.92	 0.18	 0.18	 0.18	0.20	0.0001	-0.0032	0.0039
# 100	0.2	  0.95	 0.19	 0.19	 0.19	0.20	0.0000	-0.0020	0.0024
# 110	0.2	  0.97	 0.19	 0.19	 0.19	0.20	0.0000	-0.0012	0.0014
# 120	0.2	  0.98	 0.20	 0.20	 0.20	0.20	0.0000	-0.0007	0.0009

# %%
#Plot

fig, ax1 = plt.subplots()
ax1.plot(weights, errors, label = "Fehler")
ax1.plot(weights, w_deltas, label = "w_deltas")
ax1.set_title('Gradientenabstieg')
legend = ax1.legend(loc = 'best', fancybox = True, framealpha=0.5)
plt.grid()
plt.xlabel('Gewicht w')
plt.show()
